# %% [markdown]
# # CP 1 - Fiapinho Soluções em Nuvem
# A **Fiapinho Soluções em Nuvem** é uma startup de alunos recém formados nos cursos de Cloud, Cybersecurity e Análise de Sistemas.
# Considerando que o público leigo é mais vulnerável a ataques cibernéticos, a Fiapinho buscou a **LAB501 Alunos Associados** para simplificar o acesso a VMs em nuvem.
#
# A **LAB501 Alunos Associados** é composta por três ilustres membros, sendo eles:
#
# Gustavo Baccan Gomes (RM94960)
#
# Henrique Cabral Lopes (RM94320)

# %%
# libs
# pandas: manipulação de dados
# scikit-learn: biblioteca de machine learning

# Descomente as linhas abaixo para instalar as libs
# !pip install pandas
# !pip install scikit-learn

import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.tree            import DecisionTreeClassifier

from sklearn.metrics         import accuracy_score

# %% [markdown]
# # I. Leitura de Dados
#
# Para iniciarmos este projeto, efetuamos a leitura do arquivo *csv* fornecido pelo cliente, criando, assim, nosso **dataframe** (df).

# %%
df = pd.read_csv('dados_TREINO.csv')
df
# Out:
#          Category  pslist.nproc  pslist.nppid  pslist.avg_threads  \
# 0          Benign          45.0          17.0           10.555556
# 1          Benign          47.0          19.0           11.531915
# 2          Benign          40.0          14.0           14.725000
# 3          Benign          32.0          13.0           13.500000
# 4          Benign          42.0          16.0           11.452381
# ...           ...           ...           ...                 ...
# 58591  Ransomware          37.0          15.0           10.108108
# 58592  Ransomware          37.0          14.0            9.945946
# 58593  Ransomware          38.0          15.0            9.842105
# 58594  Ransomware          37.0          15.0           10.243243
# 58595  Ransomware          38.0          15.0            9.868421
#
#        pslist.nprocs64bit  pslist.avg_handlers  dlllist.ndlls  \
# 0                     0.0           202.844444         1694.0
# 1                     0.0           242.234043         2074.0
# 2                     0.0           288.225000         1932.0
# 3                     0.0           264.281250         1445.0
# 4                     0.0           281.333333         2067.0
# ...                   ...                  ...            ...
# 58591                 0.0           215.486487         1453.0
# 58592                 0.0           190.216216         1347.0
# 58593                 0.0           210.026316         1448.0
# 58594                 0.0           215.513513         1452.0
# 58595                 0.0           213.026316         1487.0
#
#        dlllist.avg_dlls_per_proc  handles.nhandles  \
# 0                      38.500000            9129.0
# 1                      44.127660           11385.0
# 2                      48.300000           11529.0
# 3                      45.156250            8457.0
# 4                      49.214286           11816.0
# ...                          ...               ...
# 58591                  39.270270            7973.0
# 58592                  36.405405            7038.0
# 58593                  38.105263            7982.0
# 58594                  39.243243            7974.0
# 58595                  39.131579            8095.0
#
#        handles.avg_handles_per_proc  ...  svcscan.kernel_drivers  \
# 0                        212.302326  ...                   221.0
# 1                        242.234043  ...                   222.0
# 2                        288.225000  ...                   222.0
# 3                        264.281250  ...                   222.0
# 4                        281.333333  ...                   222.0
# ...                             ...  ...                     ...
# 58591                    215.486487  ...                   221.0
# 58592                    190.216216  ...                   221.0
# 58593                    215.729730  ...                   221.0
# 58594                    215.513513  ...                   221.0
# 58595                    213.026316  ...                   221.0
#
#        svcscan.fs_drivers  svcscan.process_services  \
# 0                    26.0                      24.0
# 1                    26.0                      24.0
# 2                    26.0                      27.0
# 3                    26.0                      27.0
# 4                    26.0                      24.0
# ...                   ...                       ...
# 58591                26.0                      24.0
# 58592                 NaN                      24.0
# 58593                26.0                      24.0
# 58594                26.0                      24.0
# 58595                26.0                      24.0
#
#        svcscan.shared_process_services  svcscan.interactive_process_services  \
# 0                                116.0                                   0.0
# 1                                118.0                                   0.0
# 2                                118.0                                   0.0
# 3                                118.0                                   0.0
# 4                                118.0                                   0.0
# ...                                ...                                   ...
# 58591                            116.0                                   0.0
# 58592                            116.0                                   0.0
# 58593                            116.0                                   0.0
# 58594                            116.0                                   0.0
# 58595                            116.0                                   0.0
#
#        svcscan.nactive  callbacks.ncallbacks  callbacks.nanonymous  \
# 0                121.0                  87.0                   0.0
# 1                122.0                  87.0                   0.0
# 2                120.0                  88.0                   0.0
# 3                120.0                  88.0                   0.0
# 4                124.0                  87.0                   0.0
# ...                ...                   ...                   ...
# 58591            120.0                  86.0                   0.0
# 58592            116.0                  88.0                   0.0
# 58593            120.0                  88.0                   0.0
# 58594            120.0                  87.0                   0.0
# 58595            120.0                  86.0                   0.0
#
#        callbacks.ngeneric    Class
# 0                     8.0   Benign
# 1                     8.0   Benign
# 2                     8.0   Benign
# 3                     8.0   Benign
# 4                     8.0   Benign
# ...                   ...      ...
# 58591                 8.0  Malware
# 58592                 8.0  Malware
# 58593                 8.0  Malware
# 58594                 8.0  Malware
# 58595                 8.0  Malware
#
# [58596 rows x 57 columns]

# %% [markdown]
# # II. Análise do Dataframe
#
# Após obtermos as informações do arquivo fornecido, iniciamos a análise de todas as informações contidas, como quantidade de informações, linhas, colunas e objetos.

# %%
df.sample(5)
# Out:
#          Category  pslist.nproc  pslist.nppid  pslist.avg_threads  \
# 32373  Ransomware          40.0          16.0            9.550000
# 57426  Ransomware          42.0          16.0           10.738095
# 16161      Benign          41.0          14.0           12.852074
# 9510       Benign          44.0          13.0           12.406376
# 42226     Spyware          27.0           9.0           14.000000
#
#        pslist.nprocs64bit  pslist.avg_handlers  dlllist.ndlls  \
# 32373                 0.0           204.775000         1524.0
# 57426                 0.0           209.261905         1621.0
# 16161                 0.0           289.125119         2050.0
# 9510                  0.0           278.979987         2196.0
# 42226                 0.0           269.185185         1212.0
#
#        dlllist.avg_dlls_per_proc  handles.nhandles  \
# 32373                  38.100000            8191.0
# 57426                  38.595238            8789.0
# 16161                  50.000000           11854.0
# 9510                   49.909091           12275.0
# 42226                  44.888889            7268.0
#
#        handles.avg_handles_per_proc  ...  svcscan.kernel_drivers  \
# 32373                    204.775000  ...                   221.0
# 57426                    209.261905  ...                   221.0
# 16161                    289.125119  ...                   222.0
# 9510                     278.979987  ...                   222.0
# 42226                    269.185185  ...                   221.0
#
#        svcscan.fs_drivers  svcscan.process_services  \
# 32373                26.0                      24.0
# 57426                26.0                      24.0
# 16161                26.0                      27.0
# 9510                 26.0                      27.0
# 42226                26.0                      24.0
#
#        svcscan.shared_process_services  svcscan.interactive_process_services  \
# 32373                            116.0                                   0.0
# 57426                            116.0                                   0.0
# 16161                            118.0                                   0.0
# 9510                             118.0                                   0.0
# 42226                            116.0                                   0.0
#
#        svcscan.nactive  callbacks.ncallbacks  callbacks.nanonymous  \
# 32373            119.0                  86.0                   0.0
# 57426            122.0                  87.0                   0.0
# 16161            123.0                  88.0                   0.0
# 9510             122.0                  88.0                   0.0
# 42226            120.0                  88.0                   0.0
#
#        callbacks.ngeneric    Class
# 32373                 8.0  Malware
# 57426                 8.0  Malware
# 16161                 8.0   Benign
# 9510                  8.0   Benign
# 42226                 NaN  Malware
#
# [5 rows x 57 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58596 entries, 0 to 58595
# Data columns (total 57 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Category                                58294 non-null  object
#  1   pslist.nproc                            58300 non-null  float64
#  2   pslist.nppid                            58303 non-null  float64
#  3   pslist.avg_threads                      58320 non-null  float64
#  4   pslist.nprocs64bit                      58315 non-null  float64
#  5   pslist.avg_handlers                     58312 non-null  float64
#  6   dlllist.ndlls                           58297 non-null  float64
#  7   dlllist.avg_dlls_per_proc               58281 non-null  float64
#  8   handles.nhandles                        58310 non-null  float64
#  9   handles.avg_handles_per_proc            58323 non-null  float64
#  10  handles.nport                           58311 non-null  float64
#  11  handles.nfile                           58321 non-null  float64
#  12  handles.nevent                          58301 non-null  float64
#  13  handles.ndesktop                        58301 non-null  float64
#  14  handles.nkey                            58311 non-null  float64
#  15  handles.nthread                         58316 non-null  float64
#  16  handles.ndirectory                      58298 non-null  float64
#  17  handles.nsemaphore                      58287 non-null  float64
#  18  handles.ntimer                          58315 non-null  float64
#  19  handles.nsection                        58274 non-null  float64
#  20  handles.nmutant                         58279 non-null  float64
#  21  ldrmodules.not_in_load                  58327 non-null  float64
#  22  ldrmodules.not_in_init                  58297 non-null  float64
#  23  ldrmodules.not_in_mem                   58319 non-null  float64
#  24  ldrmodules.not_in_load_avg              58280 non-null  float64
#  25  ldrmodules.not_in_init_avg              58290 non-null  float64
#  26  ldrmodules.not_in_mem_avg               58319 non-null  float64
#  27  malfind.ninjections                     58350 non-null  float64
#  28  malfind.commitCharge                    58306 non-null  float64
#  29  malfind.protection                      58296 non-null  float64
#  30  malfind.uniqueInjections                58304 non-null  float64
#  31  psxview.not_in_pslist                   58279 non-null  float64
#  32  psxview.not_in_eprocess_pool            58323 non-null  float64
#  33  psxview.not_in_ethread_pool             58300 non-null  float64
#  34  psxview.not_in_pspcid_list              58299 non-null  float64
#  35  psxview.not_in_csrss_handles            58281 non-null  float64
#  36  psxview.not_in_session                  58312 non-null  float64
#  37  psxview.not_in_deskthrd                 58294 non-null  float64
#  38  psxview.not_in_pslist_false_avg         58314 non-null  float64
#  39  psxview.not_in_eprocess_pool_false_avg  58316 non-null  float64
#  40  psxview.not_in_ethread_pool_false_avg   58296 non-null  float64
#  41  psxview.not_in_pspcid_list_false_avg    58328 non-null  float64
#  42  psxview.not_in_csrss_handles_false_avg  58286 non-null  float64
#  43  psxview.not_in_session_false_avg        58323 non-null  float64
#  44  psxview.not_in_deskthrd_false_avg       58256 non-null  float64
#  45  modules.nmodules                        58314 non-null  float64
#  46  svcscan.nservices                       58295 non-null  float64
#  47  svcscan.kernel_drivers                  58258 non-null  float64
#  48  svcscan.fs_drivers                      58309 non-null  float64
#  49  svcscan.process_services                58313 non-null  float64
#  50  svcscan.shared_process_services         58317 non-null  float64
#  51  svcscan.interactive_process_services    58325 non-null  float64
#  52  svcscan.nactive                         58315 non-null  float64
#  53  callbacks.ncallbacks                    58294 non-null  float64
#  54  callbacks.nanonymous                    58279 non-null  float64
#  55  callbacks.ngeneric                      58255 non-null  float64
#  56  Class                                   58334 non-null  object
# dtypes: float64(55), object(2)
# memory usage: 25.5+ MB

# %% [markdown]
# # III. Filtro de Dados
#
# Após análise primária da superfície dos dados, iniciamos o processo de filtragem do **dataframe**, separando as informações que não serão utilizadas ou que possam interferir neste estudo, sejam por imprecisão, sejam por poluição.

# %%
# df.dropna() é uma função que remove as linhas com valores nulos
# inplace=True é para que a função altere o dataframe original
df.dropna(inplace=True)
df
# Out:
#          Category  pslist.nproc  pslist.nppid  pslist.avg_threads  \
# 0          Benign          45.0          17.0           10.555556
# 1          Benign          47.0          19.0           11.531915
# 2          Benign          40.0          14.0           14.725000
# 3          Benign          32.0          13.0           13.500000
# 4          Benign          42.0          16.0           11.452381
# ...           ...           ...           ...                 ...
# 58588  Ransomware          37.0          15.0           10.135135
# 58590  Ransomware          37.0          15.0           10.270270
# 58591  Ransomware          37.0          15.0           10.108108
# 58594  Ransomware          37.0          15.0           10.243243
# 58595  Ransomware          38.0          15.0            9.868421
#
#        pslist.nprocs64bit  pslist.avg_handlers  dlllist.ndlls  \
# 0                     0.0           202.844444         1694.0
# 1                     0.0           242.234043         2074.0
# 2                     0.0           288.225000         1932.0
# 3                     0.0           264.281250         1445.0
# 4                     0.0           281.333333         2067.0
# ...                   ...                  ...            ...
# 58588                 0.0           215.729730         1447.0
# 58590                 0.0           215.243243         1445.0
# 58591                 0.0           215.486487         1453.0
# 58594                 0.0           215.513513         1452.0
# 58595                 0.0           213.026316         1487.0
#
#        dlllist.avg_dlls_per_proc  handles.nhandles  \
# 0                      38.500000            9129.0
# 1                      44.127660           11385.0
# 2                      48.300000           11529.0
# 3                      45.156250            8457.0
# 4                      49.214286           11816.0
# ...                          ...               ...
# 58588                  39.108108            7982.0
# 58590                  39.054054            7964.0
# 58591                  39.270270            7973.0
# 58594                  39.243243            7974.0
# 58595                  39.131579            8095.0
#
#        handles.avg_handles_per_proc  ...  svcscan.kernel_drivers  \
# 0                        212.302326  ...                   221.0
# 1                        242.234043  ...                   222.0
# 2                        288.225000  ...                   222.0
# 3                        264.281250  ...                   222.0
# 4                        281.333333  ...                   222.0
# ...                             ...  ...                     ...
# 58588                    215.729730  ...                   221.0
# 58590                    215.243243  ...                   221.0
# 58591                    215.486487  ...                   221.0
# 58594                    215.513513  ...                   221.0
# 58595                    213.026316  ...                   221.0
#
#        svcscan.fs_drivers  svcscan.process_services  \
# 0                    26.0                      24.0
# 1                    26.0                      24.0
# 2                    26.0                      27.0
# 3                    26.0                      27.0
# 4                    26.0                      24.0
# ...                   ...                       ...
# 58588                26.0                      24.0
# 58590                26.0                      24.0
# 58591                26.0                      24.0
# 58594                26.0                      24.0
# 58595                26.0                      24.0
#
#        svcscan.shared_process_services  svcscan.interactive_process_services  \
# 0                                116.0                                   0.0
# 1                                118.0                                   0.0
# 2                                118.0                                   0.0
# 3                                118.0                                   0.0
# 4                                118.0                                   0.0
# ...                                ...                                   ...
# 58588                            116.0                                   0.0
# 58590                            116.0                                   0.0
# 58591                            116.0                                   0.0
# 58594                            116.0                                   0.0
# 58595                            116.0                                   0.0
#
#        svcscan.nactive  callbacks.ncallbacks  callbacks.nanonymous  \
# 0                121.0                  87.0                   0.0
# 1                122.0                  87.0                   0.0
# 2                120.0                  88.0                   0.0
# 3                120.0                  88.0                   0.0
# 4                124.0                  87.0                   0.0
# ...                ...                   ...                   ...
# 58588            120.0                  88.0                   0.0
# 58590            119.0                  87.0                   0.0
# 58591            120.0                  86.0                   0.0
# 58594            120.0                  87.0                   0.0
# 58595            120.0                  86.0                   0.0
#
#        callbacks.ngeneric    Class
# 0                     8.0   Benign
# 1                     8.0   Benign
# 2                     8.0   Benign
# 3                     8.0   Benign
# 4                     8.0   Benign
# ...                   ...      ...
# 58588                 8.0  Malware
# 58590                 8.0  Malware
# 58591                 8.0  Malware
# 58594                 8.0  Malware
# 58595                 8.0  Malware
#
# [44091 rows x 57 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 44091 entries, 0 to 58595
# Data columns (total 57 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Category                                44091 non-null  object
#  1   pslist.nproc                            44091 non-null  float64
#  2   pslist.nppid                            44091 non-null  float64
#  3   pslist.avg_threads                      44091 non-null  float64
#  4   pslist.nprocs64bit                      44091 non-null  float64
#  5   pslist.avg_handlers                     44091 non-null  float64
#  6   dlllist.ndlls                           44091 non-null  float64
#  7   dlllist.avg_dlls_per_proc               44091 non-null  float64
#  8   handles.nhandles                        44091 non-null  float64
#  9   handles.avg_handles_per_proc            44091 non-null  float64
#  10  handles.nport                           44091 non-null  float64
#  11  handles.nfile                           44091 non-null  float64
#  12  handles.nevent                          44091 non-null  float64
#  13  handles.ndesktop                        44091 non-null  float64
#  14  handles.nkey                            44091 non-null  float64
#  15  handles.nthread                         44091 non-null  float64
#  16  handles.ndirectory                      44091 non-null  float64
#  17  handles.nsemaphore                      44091 non-null  float64
#  18  handles.ntimer                          44091 non-null  float64
#  19  handles.nsection                        44091 non-null  float64
#  20  handles.nmutant                         44091 non-null  float64
#  21  ldrmodules.not_in_load                  44091 non-null  float64
#  22  ldrmodules.not_in_init                  44091 non-null  float64
#  23  ldrmodules.not_in_mem                   44091 non-null  float64
#  24  ldrmodules.not_in_load_avg              44091 non-null  float64
#  25  ldrmodules.not_in_init_avg              44091 non-null  float64
#  26  ldrmodules.not_in_mem_avg               44091 non-null  float64
#  27  malfind.ninjections                     44091 non-null  float64
#  28  malfind.commitCharge                    44091 non-null  float64
#  29  malfind.protection                      44091 non-null  float64
#  30  malfind.uniqueInjections                44091 non-null  float64
#  31  psxview.not_in_pslist                   44091 non-null  float64
#  32  psxview.not_in_eprocess_pool            44091 non-null  float64
#  33  psxview.not_in_ethread_pool             44091 non-null  float64
#  34  psxview.not_in_pspcid_list              44091 non-null  float64
#  35  psxview.not_in_csrss_handles            44091 non-null  float64
#  36  psxview.not_in_session                  44091 non-null  float64
#  37  psxview.not_in_deskthrd                 44091 non-null  float64
#  38  psxview.not_in_pslist_false_avg         44091 non-null  float64
#  39  psxview.not_in_eprocess_pool_false_avg  44091 non-null  float64
#  40  psxview.not_in_ethread_pool_false_avg   44091 non-null  float64
#  41  psxview.not_in_pspcid_list_false_avg    44091 non-null  float64
#  42  psxview.not_in_csrss_handles_false_avg  44091 non-null  float64
#  43  psxview.not_in_session_false_avg        44091 non-null  float64
#  44  psxview.not_in_deskthrd_false_avg       44091 non-null  float64
#  45  modules.nmodules                        44091 non-null  float64
#  46  svcscan.nservices                       44091 non-null  float64
#  47  svcscan.kernel_drivers                  44091 non-null  float64
#  48  svcscan.fs_drivers                      44091 non-null  float64
#  49  svcscan.process_services                44091 non-null  float64
#  50  svcscan.shared_process_services         44091 non-null  float64
#  51  svcscan.interactive_process_services    44091 non-null  float64
#  52  svcscan.nactive                         44091 non-null  float64
#  53  callbacks.ncallbacks                    44091 non-null  float64
#  54  callbacks.nanonymous                    44091 non-null  float64
#  55  callbacks.ngeneric                      44091 non-null  float64
#  56  Class                                   44091 non-null  object
# dtypes: float64(55), object(2)
# memory usage: 19.5+ MB

# %%
df.columns
# Out:
# Index(['Category', 'pslist.nproc', 'pslist.nppid', 'pslist.avg_threads',
#        'pslist.nprocs64bit', 'pslist.avg_handlers', 'dlllist.ndlls',
#        'dlllist.avg_dlls_per_proc', 'handles.nhandles',
#        'handles.avg_handles_per_proc', 'handles.nport', 'handles.nfile',
#        'handles.nevent', 'handles.ndesktop', 'handles.nkey', 'handles.nthread',
#        'handles.ndirectory', 'handles.nsemaphore', 'handles.ntimer',
#        'handles.nsection', 'handles.nmutant', 'ldrmodules.not_in_load',
#        'ldrmodules.not_in_init', 'ldrmodules.not_in_mem',
#        'ldrmodules.not_in_load_avg', 'ldrmodules.not_in_init_avg',
#        'ldrmodules.not_in_mem_avg', 'malfind.ninjections',
#        'malfind.commitCharge', 'malfind.protection',
#        'malfind.uniqueInjections', 'psxview.not_in_pslist',
#        'psxview.not_in_eprocess_pool', 'psxview.not_in_ethread_pool',
#        'psxview.not_in_pspcid_list', 'psxview.not_in_csrss_handles',
#        'psxview.not_in_session', 'psxview.not_in_deskthrd',
#        'psxview.not_in_pslist_false_avg',
#        'psxview.not_in_eprocess_pool_false_avg',
#        'psxview.not_in_ethread_pool_false_avg',
#        'psxview.not_in_pspcid_list_false_avg',
#        'psxview.not_in_csrss_handles_false_avg',
#        'psxview.not_in_session_false_avg', 'psxview.not_in_deskthrd_false_avg',
#        'modules.nmodules', 'svcscan.nservices', 'svcscan.kernel_drivers',
#        'svcscan.fs_drivers', 'svcscan.process_services',
#        'svcscan.shared_process_services',
#        'svcscan.interactive_process_services', 'svcscan.nactive',
#        'callbacks.ncallbacks', 'callbacks.nanonymous', 'callbacks.ngeneric',
#        'Class'],
#       dtype='object')

# %% [markdown]
# # IV. Seleção de Atributos
#
# **handles.nhandles** - O número de handles abertos por um processo pode ajudar a identificar a presença de processos maliciosos que estão usando muitos recursos do sistema.
#
# **dlllist.ndlls** - A lista de DLLs carregadas por um processo pode ajudar a identificar as bibliotecas utilizadas pelo software malicioso, especialmente se elas forem diferentes das DLLs associadas a software legítimo.
#
# **pslist.avg_threads** - O número médio de threads por processo pode ajudar a identificar se um processo está tentando fazer muitas coisas ao mesmo tempo, o que pode ser uma característica comum de malwares.
#
# **ldrmodules.not_in_load** - O número de módulos não carregados pode ajudar a identificar se um processo está tentando ocultar as bibliotecas que está usando para evitar a detecção.

# %%
# df.loc[: [<coluna1>, <coluna2>]]: isso seleciona apenas as colunas desejadas
df_filtrado = df.loc[:, ['dlllist.ndlls',   'pslist.avg_threads',
                         'ldrmodules.not_in_load', 'handles.nhandles',
                         # Essas duas precisam estar na solução final:
                         'Category', 'Class'
                         ]]

df_filtrado
# Out:
#        dlllist.ndlls  pslist.avg_threads  ldrmodules.not_in_load  \
# 0             1694.0           10.555556                    53.0
# 1             2074.0           11.531915                    77.0
# 2             1932.0           14.725000                    51.0
# 3             1445.0           13.500000                    31.0
# 4             2067.0           11.452381                   102.0
# ...              ...                 ...                     ...
# 58588         1447.0           10.135135                    43.0
# 58590         1445.0           10.270270                    43.0
# 58591         1453.0           10.108108                    43.0
# 58594         1452.0           10.243243                    43.0
# 58595         1487.0            9.868421                    44.0
#
#        handles.nhandles    Category    Class
# 0                9129.0      Benign   Benign
# 1               11385.0      Benign   Benign
# 2               11529.0      Benign   Benign
# 3                8457.0      Benign   Benign
# 4               11816.0      Benign   Benign
# ...                 ...         ...      ...
# 58588            7982.0  Ransomware  Malware
# 58590            7964.0  Ransomware  Malware
# 58591            7973.0  Ransomware  Malware
# 58594            7974.0  Ransomware  Malware
# 58595            8095.0  Ransomware  Malware
#
# [44091 rows x 6 columns]

# %%
df_filtrado.describe()
# Out:
#        dlllist.ndlls  pslist.avg_threads  ldrmodules.not_in_load  \
# count   44091.000000        44091.000000            44091.000000
# mean     1810.703726           11.343569               60.842099
# std       329.586160            1.587404               18.751316
# min       670.000000            2.000000                6.000000
# 25%      1556.000000            9.972973               46.000000
# 50%      1736.000000           11.000000               57.000000
# 75%      2087.000000           12.864157               74.000000
# max      3443.000000           16.818182              240.000000
#
#        handles.nhandles
# count      4.409100e+04
# mean       1.026695e+04
# std        5.457029e+03
# min        3.514000e+03
# 25%        8.388000e+03
# 50%        9.319000e+03
# 75%        1.219500e+04
# max        1.047310e+06

# %%
df_filtrado['Class'].unique()
# Out:
# array(['Benign', 'Malware'], dtype=object)

# %%
df_filtrado['Category'].unique()
# Out:
# array(['Benign', 'Ransomware', 'Spyware', 'Trojan'], dtype=object)

# %% [markdown]
# # V. Estatísticas - Benign x Malware

# %%
df_filtrado[df_filtrado['Class']=='Benign'].describe()
# Out:
#        dlllist.ndlls  pslist.avg_threads  ldrmodules.not_in_load  \
# count   22055.000000        22055.000000            22055.000000
# mean     2083.166493           12.598901               75.616822
# std       211.131500            0.963838               14.493609
# min       911.000000            9.098129                8.000000
# 25%      2000.000000           12.075630               65.000000
# 50%      2086.000000           12.839452               74.000000
# 75%      2154.000000           13.268591               83.000000
# max      3243.000000           16.405893              141.000000
#
#        handles.nhandles
# count       22055.00000
# mean        12123.51367
# std          1157.38752
# min          5176.00000
# 25%         11705.00000
# 50%         12186.00000
# 75%         12618.50000
# max         18794.00000

# %%
df_filtrado[df_filtrado['Class']=='Malware'].describe()
# Out:
#        dlllist.ndlls  pslist.avg_threads  ldrmodules.not_in_load  \
# count   22036.000000        22036.000000            22036.000000
# mean     1538.006036           10.087155               46.054638
# std       155.135354            0.977890                7.491831
# min       670.000000            2.000000                6.000000
# 25%      1472.000000            9.613636               44.000000
# 50%      1557.000000            9.973684               46.000000
# 75%      1618.000000           10.243243               48.000000
# max      3443.000000           16.818182              240.000000
#
#        handles.nhandles
# count      2.203600e+04
# mean       8.408776e+03
# std        7.165315e+03
# min        3.514000e+03
# 25%        8.021000e+03
# 50%        8.405000e+03
# 75%        8.692000e+03
# max        1.047310e+06

# %%
df_filtrado[df_filtrado['Category']=='Benign'].describe()
# Out:
#        dlllist.ndlls  pslist.avg_threads  ldrmodules.not_in_load  \
# count   22055.000000        22055.000000            22055.000000
# mean     2083.166493           12.598901               75.616822
# std       211.131500            0.963838               14.493609
# min       911.000000            9.098129                8.000000
# 25%      2000.000000           12.075630               65.000000
# 50%      2086.000000           12.839452               74.000000
# 75%      2154.000000           13.268591               83.000000
# max      3243.000000           16.405893              141.000000
#
#        handles.nhandles
# count       22055.00000
# mean        12123.51367
# std          1157.38752
# min          5176.00000
# 25%         11705.00000
# 50%         12186.00000
# 75%         12618.50000
# max         18794.00000

# %%
df_filtrado[df_filtrado['Category']!='Benign'].describe()
# Out:
#        dlllist.ndlls  pslist.avg_threads  ldrmodules.not_in_load  \
# count   22036.000000        22036.000000            22036.000000
# mean     1538.006036           10.087155               46.054638
# std       155.135354            0.977890                7.491831
# min       670.000000            2.000000                6.000000
# 25%      1472.000000            9.613636               44.000000
# 50%      1557.000000            9.973684               46.000000
# 75%      1618.000000           10.243243               48.000000
# max      3443.000000           16.818182              240.000000
#
#        handles.nhandles
# count      2.203600e+04
# mean       8.408776e+03
# std        7.165315e+03
# min        3.514000e+03
# 25%        8.021000e+03
# 50%        8.405000e+03
# 75%        8.692000e+03
# max        1.047310e+06

# %%
# Realizar treino para classificar se é malware ou benigno
# 1. Separar os dados em X e y
# 2. Separar os dados em treino e teste
# 3. Treinar o modelo
# 4. Testar o modelo
# 5. Avaliar o modelo

X = df_filtrado.drop(columns=['Category', 'Class'])
y = df_filtrado['Class']

# %%
X
# Out:
#        dlllist.ndlls  pslist.avg_threads  ldrmodules.not_in_load  \
# 0             1694.0           10.555556                    53.0
# 1             2074.0           11.531915                    77.0
# 2             1932.0           14.725000                    51.0
# 3             1445.0           13.500000                    31.0
# 4             2067.0           11.452381                   102.0
# ...              ...                 ...                     ...
# 58588         1447.0           10.135135                    43.0
# 58590         1445.0           10.270270                    43.0
# 58591         1453.0           10.108108                    43.0
# 58594         1452.0           10.243243                    43.0
# 58595         1487.0            9.868421                    44.0
#
#        handles.nhandles
# 0                9129.0
# 1               11385.0
# 2               11529.0
# 3                8457.0
# 4               11816.0
# ...                 ...
# 58588            7982.0
# 58590            7964.0
# 58591            7973.0
# 58594            7974.0
# 58595            8095.0
#
# [44091 rows x 4 columns]

# %%
y
# Out:
# 0         Benign
# 1         Benign
# 2         Benign
# 3         Benign
# 4         Benign
#           ...
# 58588    Malware
# 58590    Malware
# 58591    Malware
# 58594    Malware
# 58595    Malware
# Name: Class, Length: 44091, dtype: object

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

print(f'X_train: {X_train.shape}')
print(f'X_test: {X_test.shape}')

print(f'y_train: {y_train.shape}')
print(f'y_test: {y_test.shape}')
# Out:
# X_train: (30863, 4)
# X_test: (13228, 4)
# y_train: (30863,)
# y_test: (13228,)

# %%
classes = list(y_train.unique())
classes.sort()

classes # confirmado, problema não é multi-classe (Mais de 2 classes), e sim binário (2 classes)
# Out:
# ['Benign', 'Malware']

# %%
clf = DecisionTreeClassifier().fit(X_train, y_train)
clf
# Out:
# DecisionTreeClassifier()

# %%
y_pred = clf.predict(X_test)
y_pred
# Out:
# array(['Malware', 'Malware', 'Benign', ..., 'Benign', 'Benign', 'Benign'],
#       dtype=object)

# %%
accuracy = accuracy_score(y_test, y_pred)

print(f"Acurácia: {round(accuracy, 4) * 100}%")
# Out:
# Acurácia: 99.85000000000001%

# %%
# Utilizando outro método de treino
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier().fit(X_train, y_train)
clf
# Out:
# RandomForestClassifier()

# %%
y_pred = clf.predict(X_test)
y_pred
# Out:
# array(['Malware', 'Malware', 'Benign', ..., 'Benign', 'Benign', 'Benign'],
#       dtype=object)

# %%
accuracy = accuracy_score(y_test, y_pred)

print(f"Acurácia: {round(accuracy, 4) * 100}%")
# Out:
# Acurácia: 99.89%
